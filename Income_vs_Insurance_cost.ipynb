# %% [markdown]
# <a href="https://colab.research.google.com/github/PhilllipK/Income-vs-Insurance-cost/blob/main/Income_vs_Insurance_cost.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from scipy.stats import ttest_ind
from scipy.stats import pearsonr
import statsmodels.formula.api as smf

# %%
total = pd.read_csv('Insurance cost for states and counties w_ per capita income.csv')
cost = list(total["Cost"])
for i in range(len(cost)):
  if len(cost[i]) == 5:
    cost[i] = cost[i][:1] + cost[i][2:]
  cost[i] = int(cost[i])

income = list(total["Income"])
for i in range(len(income)):
  comma = income[i].find(",")
  income[i] = income[i][:comma] + income[i][comma+1:]
  income[i] = int(income[i])

total["Cost"] = cost
total["Income"] = income
total
# Out:
#          County  Cost      State  Income
# 0        Apache   853    Arizona   45633
# 1       Cochise  1689    Arizona   50195
# 2      Coconino   899    Arizona   58933
# 3          Gila   853    Arizona   50505
# 4        Graham   853    Arizona   40981
# ...         ...   ...        ...     ...
# 1011   Waukesha  1816  Wisconsin   87582
# 1012    Waupaca  2373  Wisconsin   54632
# 1013   Waushara  1576  Wisconsin   46697
# 1014  Winnebago  1312  Wisconsin   56878
# 1015       Wood  1087  Wisconsin   53162
#
# [1016 rows x 4 columns]

# %%
info = pearsonr(cost, income)

print("Correlation coefficent: "+ str(info[0]))
print("p-value: "+ str(info[1]))
# Out:
# Correlation coefficent: 0.2305805473437141
# p-value: 9.981653865298007e-14

# %%
newdf = []

for i in range(len(cost)):
  newdf.append([income[i],cost[i]])

newdf = pd.DataFrame(newdf)

model = smf.ols('cost ~ income', data=newdf)
model = model.fit()
model.params
# Out:
# Intercept    1403.817999
# income          0.010021
# dtype: float64

# %%
r2 = model.rsquared
print(r2)
# Out:
# 0.05316738881332661
